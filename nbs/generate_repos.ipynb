# %% [markdown]
# # Generar archivo repos.json en base a una organización

# %%
import sys
from pathlib import Path

project_root = Path().cwd().parent
scripts_path = project_root / "scripts"
if str(scripts_path) not in sys.path:
    sys.path.insert(0, str(scripts_path))

print("Notebook working directory:", Path().cwd())
print("Project root directory:", project_root)
print("Scripts directory:", scripts_path)
print("Importing from: generate_github_api.py")
# Out:
# Notebook working directory: /workspaces/TareaGitLeaks/nbs
# Project root directory: /workspaces/TareaGitLeaks
# Scripts directory: /workspaces/TareaGitLeaks/scripts
# Importing from: generate_github_api.py

# %%
from generate_github_api import GetReposGitHubAPI

print("Import correctamente: GetReposGitHubAPI")
# Out:
# Import correctamente: GetReposGitHubAPI

# %%
repos_path = project_root / "data" / "repos"
results_path = project_root / "data" / "repos.json"

analyzer = GetReposGitHubAPI(repos_path, "vercel")

# %%
analyzer.bump_to_json(results_path, 25)
