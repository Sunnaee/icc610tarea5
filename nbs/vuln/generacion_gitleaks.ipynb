# %% [markdown]
# # Ejecución de análisis de seguridad con GitLeaks

# %%
import sys
from pathlib import Path

project_root = Path().cwd().parent.parent
scripts_path = project_root / "scripts"
if str(scripts_path) not in sys.path:
    sys.path.insert(0, str(scripts_path))

print("Notebook working directory:", Path().cwd())
print("Project root directory:", project_root)
print("Scripts directory:", scripts_path)
print("Importing from: generate_gitleaks.py")
# Out:
# Notebook working directory: /workspaces/TareaGitLeaks/nbs/vuln
# Project root directory: /workspaces/TareaGitLeaks
# Scripts directory: /workspaces/TareaGitLeaks/scripts
# Importing from: generate_gitleaks.py

# %%
from generate_gitleaks import GitLeaksAnalyzer

print("Import correctamente: GitLeaksAnalyzer")
# Out:
# Import correctamente: GitLeaksAnalyzer

# %%
repos_path = project_root / "data" / "repos"
results_path = project_root / "data" / "results"

analyzer = GitLeaksAnalyzer(
    str(repos_path),
    str(results_path)
)

# %%
analyzer.run()
# Out:
# INFO | Analizando el repositorio: data/repos/ai
# INFO | Ejecutando Gitleaks en el repositorio: ai
# INFO | Gitleaks completado para ai
# INFO | Analizando el repositorio: data/repos/chatbot
# INFO | Ejecutando Gitleaks en el repositorio: chatbot
# INFO | Gitleaks completado para chatbot
# INFO | Analizando el repositorio: data/repos/commerce
# INFO | Ejecutando Gitleaks en el repositorio: commerce
# INFO | Gitleaks completado para commerce
# INFO | Analizando el repositorio: data/repos/examples
# INFO | Ejecutando Gitleaks en el repositorio: examples
# INFO | Gitleaks completado para examples
# INFO | Analizando el repositorio: data/repos/hazel
# INFO | Ejecutando Gitleaks en el repositorio: hazel
# INFO | Gitleaks completado para hazel
# INFO | Analizando el repositorio: data/repos/hyper
# INFO | Ejecutando Gitleaks en el repositorio: hyper
# INFO | Gitleaks completado para hyper
# INFO | Analizando el repositorio: data/repos/kirimase
# ...
